# %% [markdown]
# 東京都多摩小平保健所

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('pollen_2017-2018.csv').applymap(lambda x: max(0, x))

# %%
data.to_csv('pollen_2017-2018_zerofill.csv', index=False)

# %%
pd.read_csv('pollen_2017-2018_zerofill.csv')
# Out:
#       month  day  hour  2018  2017
# 0         2    1     1   4.0     0
# 1         2    1     2  12.0     4
# 2         2    1     3   8.0    12
# 3         2    1     4   8.0     0
# 4         2    1     5   0.0     4
# 5         2    1     6   8.0     0
# 6         2    1     7  12.0     0
# 7         2    1     8   4.0     8
# 8         2    1     9   0.0    12
# 9         2    1    10   8.0    36
# 10        2    1    11   8.0    20
# 11        2    1    12   8.0    24
# 12        2    1    13   4.0    28
# 13        2    1    14   0.0    36
# 14        2    1    15   0.0    24
# 15        2    1    16   0.0    49
# 16        2    1    17   0.0    61
# 17        2    1    18   0.0    73
# 18        2    1    19   0.0    86
# 19        2    1    20   0.0    77
# 20        2    1    21   0.0    45
# 21        2    1    22   0.0    20
# 22        2    1    23   0.0     4
# 23        2    1    24   0.0    20
# 24        2    2     1   0.0     8
# 25        2    2     2   0.0     4
# ...
